# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt

import bitcoin.db as db
df = db.get_all_data_from_pas(pas=500)
df.describe()
# Out:
# 2018-03-28 14:14:37,029 root         INFO     Load data from SQL.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#               open  tw_sentiment  reddit_sentiment  google_sentiment  \
# count    63.000000     63.000000         63.000000         63.000000
# mean   7223.094286      0.063361          0.058088          0.022232
# std     695.720701      0.069424          0.035126          0.059148
# min    6053.590000     -0.024729         -0.023345         -0.086034
# 25%    6800.220000      0.028543          0.034897         -0.015985
# 50%    7104.830000      0.053470          0.053134          0.016023
# 75%    7415.490000      0.073478          0.082097          0.056610
# max    9322.010000      0.361210          0.163680          0.190463
#
#              close          time    percent         up
# count    63.000000  6.300000e+01  63.000000  63.000000
# mean   7175.340159  1.521237e+09  -0.555302   0.365079
# ...

# %%
import bitcoin.validation as val
result = val.how_many_up_and_down(df=df)
result.head()
# Out:
# n => median => 2
#      n  side    percent
# 0  7.0   0.0 -16.706912
# 1  1.0   1.0   2.991787
# 2  2.0   0.0 -11.155087
# 3  1.0   1.0   2.887754
# 4  1.0   0.0   0.096443

# %%
result.describe()
# Out:
#                n       side    percent
# count  29.000000  29.000000  29.000000
# mean    2.137931   0.482759  -1.062243
# std     1.432384   0.508548   7.487472
# min     1.000000   0.000000 -16.706912
# 25%     1.000000   0.000000  -6.497994
# 50%     2.000000   0.000000   0.096443
# 75%     3.000000   1.000000   2.991787
# max     7.000000   1.000000  15.167529

# %%
val.test_money_step(df=df, num=1)
# Out:
# 2018-03-28 14:15:18,019 root         INFO     BUY
# 2018-03-28 14:15:18,020 root         INFO     SELL
# 2018-03-28 14:15:18,022 root         INFO     BUY
# 2018-03-28 14:15:18,023 root         INFO     SELL
# 2018-03-28 14:15:18,024 root         INFO     BUY
# 2018-03-28 14:15:18,026 root         INFO     SELL
# 2018-03-28 14:15:18,027 root         INFO     BUY
# 2018-03-28 14:15:18,029 root         INFO     SELL
# 2018-03-28 14:15:18,030 root         INFO     BUY
# 2018-03-28 14:15:18,032 root         INFO     SELL
# 2018-03-28 14:15:18,033 root         INFO     BUY
# 2018-03-28 14:15:18,034 root         INFO     SELL
# 2018-03-28 14:15:18,035 root         INFO     BUY
# 2018-03-28 14:15:18,037 root         INFO     SELL
# 2018-03-28 14:15:18,038 root         INFO     BUY
# 2018-03-28 14:15:18,040 root         INFO     TEST From 2018-03-22 03:38:00 to 2018-03-28 03:20:00
# 2018-03-28 14:15:18,041 root         INFO     With prediction 1029.75 euros
# ...
