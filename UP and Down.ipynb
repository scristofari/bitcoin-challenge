# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt

import bitcoin.db as db
df = db.get_all_data_from_pas(pas=120)
# Out:
# 2018-03-28 19:03:56,005 root         INFO     Load data from SQL.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import bitcoin.train as t
t.train_anomaly(df=df)

# %%
import bitcoin.validation as val
val.order_up_and_down(df, 80)
# Out:
# 2018-03-28 19:03:57,096 root         INFO     Load data from SQL.
# 2018-03-28 19:03:57,513 root         INFO     BUY
# 2018-03-28 19:03:58,129 root         INFO     SELL
# 2018-03-28 19:03:58,186 root         INFO     BUY
# 2018-03-28 19:03:58,550 root         INFO     SELL
# 2018-03-28 19:03:58,660 root         INFO     BUY
# 2018-03-28 19:03:58,741 root         INFO     SELL
# 2018-03-28 19:03:58,811 root         INFO     BUY
# 2018-03-28 19:03:58,818 root         INFO     SELL
# 2018-03-28 19:03:58,873 root         INFO     BUY
# 2018-03-28 19:03:58,931 root         INFO     SELL
# 2018-03-28 19:03:59,040 root         INFO     BUY
# 2018-03-28 19:03:59,182 root         INFO     SELL
# 2018-03-28 19:03:59,291 root         INFO     BUY
# 2018-03-28 19:03:59,312 root         INFO     SELL
# 2018-03-28 19:03:59,322 root         INFO     BUY
# 2018-03-28 19:03:59,336 root         INFO     SELL
# 2018-03-28 19:03:59,347 root         INFO     BUY
# ...
